# %%
import pandas as pd

# %%
import pandas as pd

dataset = pd.read_csv('properties_data.csv')
price_summary = dataset['price'].describe().apply('{:,.2f}'.format)
print(price_summary)
# Out:
# count         1,905.00
# mean      2,085,829.87
# std       2,913,199.96
# min         220,000.00
# 25%         890,000.00
# 50%       1,400,000.00
# 75%       2,200,000.00
# max      35,000,000.00
# Name: price, dtype: object

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.hist(dataset['price'], bins=15, color='orange')
plt.xlabel('Price')
plt.ylabel('Number of Properties')
plt.title('Distribution of Property Price', fontsize=10, color='black')

plt.show()

# %%
import pandas as pd

dataset = pd.read_csv('properties_data.csv')
price_summary = dataset['quality'].describe()
print(price_summary)
# Out:
# count       1905
# unique         4
# top       Medium
# freq        1146
# Name: quality, dtype: object

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.hist(dataset['quality'], bins=15,color='darkblue')

# Add the x and y axis titles
plt.xlabel('Quality')
plt.ylabel('Number of Properties')

plt.title('Distribution of Property Quality', fontsize=10, color='black')

plt.show()

# %%
pip install seaborn
# Out:
# ...
#
# ...

# %%
dataset2 = dataset.drop(['neighborhood', 'longitude', 'latitude','id','quality'], axis=1)

# %%
from sklearn.preprocessing import LabelEncoder 
label_encoder = LabelEncoder() 
dataset2['quality'] = label_encoder.fit_transform(dataset2['quality'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ACER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'quality'
#
# ...

# %%
import matplotlib.pyplot as mp 
import pandas as pd 
import seaborn as sns
  
# plotting correlation heatmap 
dataplot = sns.heatmap(dataset2.corr())

# displaying heatmap 
mp.show()

# %%
import seaborn as sns
 
fig = plt.figure(figsize=(5,10))
ax = sns.heatmap(dataset2.corr()[['price']].abs().sort_values('price', ascending=False), annot=True,annot_kws = {"size":12},cmap='Blues',cbar=False)
ax.set_title('Correlation Coefficient for Price',fontsize=18)
ax.tick_params(axis = "both",labelsize=12)
y_min,y_max = ax.get_ylim()
ax.set_ylim(top=y_max+1)
# Out:
# (33.0, 1.0)
